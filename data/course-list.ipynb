# %%
import pandas as pd

# %%
df = pd.read_csv("sp25-ug-cs.csv")
df.head()
# Out:
#   Day Start Time End Time                                   Course  \
# 0  MW       8:30     9:45          Information Security and Ethics
# 1  MW       8:30     9:45          Information Security and Ethics
# 2  MW       8:30     9:45                         Pakistan History
# 3  MW       8:30     9:45                  Competitive Programming
# 4  MW       8:30     9:45  Introduction to Artificial Intelligence
#
#    UMS Class No.            Teacher
# 0          98642     Dr. Imran Khan
# 1          98352     Dr. Imran Khan
# 2          98354   Dr. Jaffar Ahmed
# 3          98358     Dr. Imran Rauf
# 4          98355  Dr. Syed Ali Raza

# %%
unique_check = df['Course'].value_counts().to_dict()
unique_check = dict(sorted(unique_check.items()))

for course, count in unique_check.items():
    print(f"{course : >50} : {count : >2}")
# Out:
#         Application Development for mobile devices :  1
#                              Applied Data Analysis :  1
#                             Business Intelligience :  2
#                                        Calculus-II :  5
#                            Competitive Programming :  2
#        Computer Architecture and Assembly Language : 10
#              Computer Communication and Networking : 10
#                                    Data Structures :  2
#                                   Data Warehousing :  1
#                   Design and Analysis of Algorithm :  4
#                                  Digital Forensics :  1
#                               Discrete Mathematics :  5
#                    Information Security and Ethics :  4
#                                 Interaction Design :  1
#            Introduction to Artificial Intelligence :  5
#                    Introduction to Computer Vision :  1
#                        Introduction to Programming :  2
# ...
